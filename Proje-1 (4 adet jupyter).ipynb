# %%
import pandas as pd

# %%
import numpy as nd

# %%
ri = pd.read_csv("police.csv")
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (8,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
ri
# Out:
#                    id state   stop_date stop_time location_raw  county_name  \
# 0       RI-2005-00001    RI  2005-01-02     01:55      Zone K1          NaN
# 1       RI-2005-00002    RI  2005-01-02     20:30      Zone X4          NaN
# 2       RI-2005-00003    RI  2005-01-04     11:30      Zone X1          NaN
# 3       RI-2005-00004    RI  2005-01-04     12:55      Zone X4          NaN
# 4       RI-2005-00005    RI  2005-01-06     01:30      Zone X4          NaN
# ...               ...   ...         ...       ...          ...          ...
# 509676       RI-NA-06    RI         NaN       NaN      Zone NA          NaN
# 509677       RI-NA-07    RI         NaN       NaN      Zone NA          NaN
# 509678       RI-NA-08    RI         NaN       NaN      Zone NA          NaN
# 509679       RI-NA-09    RI         NaN       NaN      Zone NA          NaN
# 509680       RI-NA-10    RI         NaN       NaN      Zone NA          NaN
#
# ...

# %%
ri.head(50)
# Out:
#                id state   stop_date stop_time location_raw  county_name  \
# 0   RI-2005-00001    RI  2005-01-02     01:55      Zone K1          NaN
# 1   RI-2005-00002    RI  2005-01-02     20:30      Zone X4          NaN
# 2   RI-2005-00003    RI  2005-01-04     11:30      Zone X1          NaN
# 3   RI-2005-00004    RI  2005-01-04     12:55      Zone X4          NaN
# 4   RI-2005-00005    RI  2005-01-06     01:30      Zone X4          NaN
# 5   RI-2005-00006    RI  2005-01-12     08:05      Zone X1          NaN
# 6   RI-2005-00007    RI  2005-01-18     08:15      Zone K3          NaN
# 7   RI-2005-00008    RI  2005-01-18     17:13      Zone X1          NaN
# 8   RI-2005-00009    RI  2005-01-23     23:15      Zone K3          NaN
# 9   RI-2005-00010    RI  2005-01-24     20:32      Zone K1          NaN
# 10  RI-2005-00011    RI  2005-02-09     03:05      Zone X4          NaN
# 11  RI-2005-00012    RI  2005-02-11     01:20      Zone K3          NaN
# ...

# %%
ri.isnull()
# Out:
#            id  state  stop_date  stop_time  location_raw  county_name  \
# 0       False  False      False      False         False         True
# 1       False  False      False      False         False         True
# 2       False  False      False      False         False         True
# 3       False  False      False      False         False         True
# 4       False  False      False      False         False         True
# ...       ...    ...        ...        ...           ...          ...
# 509676  False  False       True       True         False         True
# 509677  False  False       True       True         False         True
# 509678  False  False       True       True         False         True
# 509679  False  False       True       True         False         True
# 509680  False  False       True       True         False         True
#
#         county_fips  fine_grained_location  police_department  driver_gender  \
# ...

# %%
ri.isnull().sum()
# Out:
# id                            0
# state                         0
# stop_date                    10
# stop_time                    10
# location_raw                  0
# county_name              509681
# county_fips              509681
# fine_grained_location    509681
# police_department            10
# driver_gender             29097
# driver_age_raw            29049
# driver_age                30695
# driver_race_raw           29073
# driver_race               29073
# violation_raw             29073
# violation                 29073
# search_conducted             10
# search_type_raw          491919
# search_type              491919
# contraband_found              0
# stop_outcome              29073
# is_arrested               29073
# stop_duration             29073
# out_of_state              29881
# drugs_related_stop            0
# district                      0
# dtype: int64

# %%
ri = ri.drop(["county_name", "fine_grained_location"], axis = 1)

# %%
ri
# Out:
#                    id state   stop_date stop_time location_raw  county_fips  \
# 0       RI-2005-00001    RI  2005-01-02     01:55      Zone K1          NaN
# 1       RI-2005-00002    RI  2005-01-02     20:30      Zone X4          NaN
# 2       RI-2005-00003    RI  2005-01-04     11:30      Zone X1          NaN
# 3       RI-2005-00004    RI  2005-01-04     12:55      Zone X4          NaN
# 4       RI-2005-00005    RI  2005-01-06     01:30      Zone X4          NaN
# ...               ...   ...         ...       ...          ...          ...
# 509676       RI-NA-06    RI         NaN       NaN      Zone NA          NaN
# 509677       RI-NA-07    RI         NaN       NaN      Zone NA          NaN
# 509678       RI-NA-08    RI         NaN       NaN      Zone NA          NaN
# 509679       RI-NA-09    RI         NaN       NaN      Zone NA          NaN
# 509680       RI-NA-10    RI         NaN       NaN      Zone NA          NaN
#
# ...

# %%
ri.shape
# Out:
# (509681, 24)

# %%
ri.isnull()
# Out:
#            id  state  stop_date  stop_time  location_raw  county_fips  \
# 0       False  False      False      False         False         True
# 1       False  False      False      False         False         True
# 2       False  False      False      False         False         True
# 3       False  False      False      False         False         True
# 4       False  False      False      False         False         True
# ...       ...    ...        ...        ...           ...          ...
# 509676  False  False       True       True         False         True
# 509677  False  False       True       True         False         True
# 509678  False  False       True       True         False         True
# 509679  False  False       True       True         False         True
# 509680  False  False       True       True         False         True
#
#         police_department  driver_gender  driver_age_raw  driver_age  ...  \
# ...

# %%
ri.isnull().sum()
# Out:
# id                         0
# state                      0
# stop_date                 10
# stop_time                 10
# location_raw               0
# county_fips           509681
# police_department         10
# driver_gender          29097
# driver_age_raw         29049
# driver_age             30695
# driver_race_raw        29073
# driver_race            29073
# violation_raw          29073
# violation              29073
# search_conducted          10
# search_type_raw       491919
# search_type           491919
# contraband_found           0
# stop_outcome           29073
# is_arrested            29073
# stop_duration          29073
# out_of_state           29881
# drugs_related_stop         0
# district                   0
# dtype: int64

# %%
ri.isnull().sum() # Her sutunun eksik degeri.
# Out:
# id                         0
# state                      0
# stop_date                 10
# stop_time                 10
# location_raw               0
# county_fips           509681
# police_department         10
# driver_gender          29097
# driver_age_raw         29049
# driver_age             30695
# driver_race_raw        29073
# driver_race            29073
# violation_raw          29073
# violation              29073
# search_conducted          10
# search_type_raw       491919
# search_type           491919
# contraband_found           0
# stop_outcome           29073
# is_arrested            29073
# stop_duration          29073
# out_of_state           29881
# drugs_related_stop         0
# district                   0
# dtype: int64

# %%
ri.dropna(subset =["driver_gender"], inplace = True) # driver_gender sutununun eksik verilerini sildi.

# %%
ri
# Out:
#                    id state   stop_date stop_time location_raw  county_fips  \
# 0       RI-2005-00001    RI  2005-01-02     01:55      Zone K1          NaN
# 1       RI-2005-00002    RI  2005-01-02     20:30      Zone X4          NaN
# 3       RI-2005-00004    RI  2005-01-04     12:55      Zone X4          NaN
# 4       RI-2005-00005    RI  2005-01-06     01:30      Zone X4          NaN
# 5       RI-2005-00006    RI  2005-01-12     08:05      Zone X1          NaN
# ...               ...   ...         ...       ...          ...          ...
# 509666  RI-2015-47061    RI  2015-12-31     22:46      Zone X1          NaN
# 509667  RI-2015-47062    RI  2015-12-31     22:47      Zone X4          NaN
# 509668  RI-2015-47063    RI  2015-12-31     23:08      Zone X3          NaN
# 509669  RI-2015-47064    RI  2015-12-31     23:44      Zone K2          NaN
# 509670  RI-2015-47065    RI  2015-12-31     23:48      Zone K3          NaN
#
# ...

# %%
ri.isnull().sum() # driver_gender de hatali (missing) satirlarin gittigi goruldu.
# Out:
# id                         0
# state                      0
# stop_date                  0
# stop_time                  0
# location_raw               0
# county_fips           480584
# police_department          0
# driver_gender              0
# driver_age_raw             1
# driver_age              1638
# driver_race_raw            0
# driver_race                0
# violation_raw              0
# violation                  0
# search_conducted           0
# search_type_raw       462822
# search_type           462822
# contraband_found           0
# stop_outcome               0
# is_arrested                0
# stop_duration              0
# out_of_state             808
# drugs_related_stop         0
# district                   0
# dtype: int64

# %%
ri.shape
# Out:
# (480584, 24)

# %%
ri["is_arrested"]
# Out:
# 0         False
# 1         False
# 3         False
# 4         False
# 5         False
#           ...
# 509666    False
# 509667    False
# 509668    False
# 509669    False
# 509670    False
# Name: is_arrested, Length: 480584, dtype: object

# %%
ri.dtypes
# Out:
# id                     object
# state                  object
# stop_date              object
# stop_time              object
# location_raw           object
# county_fips           float64
# police_department      object
# driver_gender          object
# driver_age_raw        float64
# driver_age            float64
# driver_race_raw        object
# driver_race            object
# violation_raw          object
# violation              object
# search_conducted       object
# search_type_raw        object
# search_type            object
# contraband_found         bool
# stop_outcome           object
# is_arrested            object
# stop_duration          object
# out_of_state           object
# drugs_related_stop       bool
# district               object
# dtype: object

# %%
type(ri["is_arrested"])
# Out:
# pandas.core.series.Series

# %%
ri = ri.astype({"is_arrested": bool})

# %%
ri.dtypes # is_arrested in bool oldugu goruldu.
# Out:
# id                     object
# state                  object
# stop_date              object
# stop_time              object
# location_raw           object
# county_fips           float64
# police_department      object
# driver_gender          object
# driver_age_raw        float64
# driver_age            float64
# driver_race_raw        object
# driver_race            object
# violation_raw          object
# violation              object
# search_conducted       object
# search_type_raw        object
# search_type            object
# contraband_found         bool
# stop_outcome           object
# is_arrested              bool
# stop_duration          object
# out_of_state           object
# drugs_related_stop       bool
# district               object
# dtype: object

# %%
ri
# Out:
#                    id state   stop_date stop_time location_raw  county_fips  \
# 0       RI-2005-00001    RI  2005-01-02     01:55      Zone K1          NaN
# 1       RI-2005-00002    RI  2005-01-02     20:30      Zone X4          NaN
# 3       RI-2005-00004    RI  2005-01-04     12:55      Zone X4          NaN
# 4       RI-2005-00005    RI  2005-01-06     01:30      Zone X4          NaN
# 5       RI-2005-00006    RI  2005-01-12     08:05      Zone X1          NaN
# ...               ...   ...         ...       ...          ...          ...
# 509666  RI-2015-47061    RI  2015-12-31     22:46      Zone X1          NaN
# 509667  RI-2015-47062    RI  2015-12-31     22:47      Zone X4          NaN
# 509668  RI-2015-47063    RI  2015-12-31     23:08      Zone X3          NaN
# 509669  RI-2015-47064    RI  2015-12-31     23:44      Zone K2          NaN
# 509670  RI-2015-47065    RI  2015-12-31     23:48      Zone K3          NaN
#
# ...

# %%
pd.to_datetime(ri["stop_date"]+" "+ri["stop_time"], format = "%Y-%m-%d %H:%M")
# Out:
# 0        2005-01-02 01:55:00
# 1        2005-01-02 20:30:00
# 3        2005-01-04 12:55:00
# 4        2005-01-06 01:30:00
# 5        2005-01-12 08:05:00
#                  ...
# 509666   2015-12-31 22:46:00
# 509667   2015-12-31 22:47:00
# 509668   2015-12-31 23:08:00
# 509669   2015-12-31 23:44:00
# 509670   2015-12-31 23:48:00
# Length: 480584, dtype: datetime64[ns]

# %%
ri["stop_datetime"] = pd.to_datetime(ri["stop_date"]+" "+ri["stop_time"], format = "%Y-%m-%d %H:%M")

# %%
ri["stop_datetime"].dt.strftime("%Y-%m-%d %H:%M")
# Out:
# 0         2005-01-02 01:55
# 1         2005-01-02 20:30
# 3         2005-01-04 12:55
# 4         2005-01-06 01:30
# 5         2005-01-12 08:05
#                 ...
# 509666    2015-12-31 22:46
# 509667    2015-12-31 22:47
# 509668    2015-12-31 23:08
# 509669    2015-12-31 23:44
# 509670    2015-12-31 23:48
# Name: stop_datetime, Length: 480584, dtype: object

# %%
ri
# Out:
#                    id state   stop_date stop_time location_raw  county_fips  \
# 0       RI-2005-00001    RI  2005-01-02     01:55      Zone K1          NaN
# 1       RI-2005-00002    RI  2005-01-02     20:30      Zone X4          NaN
# 3       RI-2005-00004    RI  2005-01-04     12:55      Zone X4          NaN
# 4       RI-2005-00005    RI  2005-01-06     01:30      Zone X4          NaN
# 5       RI-2005-00006    RI  2005-01-12     08:05      Zone X1          NaN
# ...               ...   ...         ...       ...          ...          ...
# 509666  RI-2015-47061    RI  2015-12-31     22:46      Zone X1          NaN
# 509667  RI-2015-47062    RI  2015-12-31     22:47      Zone X4          NaN
# 509668  RI-2015-47063    RI  2015-12-31     23:08      Zone X3          NaN
# 509669  RI-2015-47064    RI  2015-12-31     23:44      Zone K2          NaN
# 509670  RI-2015-47065    RI  2015-12-31     23:48      Zone K3          NaN
#
# ...

# %%
ri.dtypes
# Out:
# id                            object
# state                         object
# stop_date                     object
# stop_time                     object
# location_raw                  object
# county_fips                  float64
# police_department             object
# driver_gender                 object
# driver_age_raw               float64
# driver_age                   float64
# driver_race_raw               object
# driver_race                   object
# violation_raw                 object
# violation                     object
# search_conducted              object
# search_type_raw               object
# search_type                   object
# contraband_found                bool
# stop_outcome                  object
# is_arrested                     bool
# stop_duration                 object
# out_of_state                  object
# drugs_related_stop              bool
# district                      object
# stop_datetime         datetime64[ns]
# dtype: object

# %%
ri.set_index('stop_datetime', inplace = True)

# %%
ri.index.names
# Out:
# FrozenList(['stop_datetime'])

# %%
ri
# Out:
#                                 id state   stop_date stop_time location_raw  \
# stop_datetime
# 2005-01-02 01:55:00  RI-2005-00001    RI  2005-01-02     01:55      Zone K1
# 2005-01-02 20:30:00  RI-2005-00002    RI  2005-01-02     20:30      Zone X4
# 2005-01-04 12:55:00  RI-2005-00004    RI  2005-01-04     12:55      Zone X4
# 2005-01-06 01:30:00  RI-2005-00005    RI  2005-01-06     01:30      Zone X4
# 2005-01-12 08:05:00  RI-2005-00006    RI  2005-01-12     08:05      Zone X1
# ...                            ...   ...         ...       ...          ...
# 2015-12-31 22:46:00  RI-2015-47061    RI  2015-12-31     22:46      Zone X1
# 2015-12-31 22:47:00  RI-2015-47062    RI  2015-12-31     22:47      Zone X4
# 2015-12-31 23:08:00  RI-2015-47063    RI  2015-12-31     23:08      Zone X3
# 2015-12-31 23:44:00  RI-2015-47064    RI  2015-12-31     23:44      Zone K2
# 2015-12-31 23:48:00  RI-2015-47065    RI  2015-12-31     23:48      Zone K3
#
# ...

# %%
ri['violation'].unique()
# Out:
# array(['Speeding', 'Equipment', 'Other', 'Moving violation',
#        'Registration/plates', 'Seat belt'], dtype=object)

# %%
ri['violation'].value_counts()
# Out:
# Speeding               268736
# Moving violation        90228
# Equipment               61250
# Other                   24216
# Registration/plates     19830
# Seat belt               16324
# Name: violation, dtype: int64

# %%
ri['violation'].value_counts().sum()
# Out:
# 480584

# %%
ri.violation.value_counts(normalize=True)
# Out:
# Speeding               0.559186
# Moving violation       0.187747
# Equipment              0.127449
# Other                  0.050389
# Registration/plates    0.041262
# Seat belt              0.033967
# Name: violation, dtype: float64

# %%
female = ri[ri.driver_gender == 'F']

# %%
male = ri[ri.driver_gender == 'M']

# %%
female.violation.value_counts(normalize = True)
# Out:
# Speeding               0.657308
# Moving violation       0.136581
# Equipment              0.107055
# Registration/plates    0.043077
# Other                  0.028908
# Seat belt              0.027071
# Name: violation, dtype: float64

# %%
male.violation.value_counts(normalize = True)
# Out:
# Speeding               0.522364
# Moving violation       0.206948
# Equipment              0.135102
# Other                  0.058450
# Registration/plates    0.040581
# Seat belt              0.036555
# Name: violation, dtype: float64

# %%
female_and_speeding = ri[(ri.driver_gender == 'F') & (ri.violation == 'Speeding')]

# %%
male_and_speeding = ri[(ri.driver_gender == 'M') & (ri.violation == 'Speeding')]

# %%
female_and_speeding.stop_outcome.value_counts(normalize = True)
# Out:
# Citation            0.953247
# Warning             0.039003
# Arrest Driver       0.005290
# Arrest Passenger    0.001033
# N/D                 0.000905
# No Action           0.000522
# Name: stop_outcome, dtype: float64

# %%
male_and_speeding.stop_outcome.value_counts(normalize = True)
# Out:
# Citation            0.944636
# Warning             0.036086
# Arrest Driver       0.015767
# Arrest Passenger    0.001265
# N/D                 0.001183
# No Action           0.001063
# Name: stop_outcome, dtype: float64

# %%
ri.search_conducted.dtype
# Out:
# dtype('O')

# %%
ri.search_conducted.mean()
# Out:
# 0.036959199640437465

# %%
ri.groupby('driver_gender').search_conducted.mean()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-46-3448b24ff934> in <module>
# ----> 1 ri.groupby('driver_gender').search_conducted.mean()
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, *args, **kwargs)
#    1230         nv.validate_groupby_func("mean", args, kwargs, ["numeric_only"])
#    1231         return self._cython_agg_general(
# -> 1232             "mean", alt=lambda x, axis: Series(x).mean(**kwargs), **kwargs
#    1233         )
#    1234
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#     905
#     906         if len(output) == 0:
# --> 907             raise DataError("No numeric types to aggregate")
#     908
#     909         return self._wrap_aggregated_output(output)
#
# DataError: No numeric types to aggregate

# %%
ri.groupby(['violation', 'driver_gender'])[['search_conducted']].mean()

# %%
ri.search_type.value_counts()

# %%
ri['frisk'] = ri.search_type.str.contains('Protective Frisk', na = False)

# %%
ri.frisk.dtype
# Out:
# dtype('bool')

# %%
ri.frisk.sum()
# Out:
# 1598

# %%
searched = ri[ri.search_conducted == True]

# %%
searched.frisk.mean()
# Out:
# 0.08996734601959239

# %%
searched.groupby('driver_gender').frisk.mean()
# Out:
# driver_gender
# F    0.066694
# M    0.093707
# Name: frisk, dtype: float64

# %%
ri.is_arrested.mean()
# Out:
# 0.03454755048024903

# %%
ri.groupby(ri.index.hour).is_arrested.mean()
# Out:
# stop_datetime
# 0     0.052151
# 1     0.067127
# 2     0.061067
# 3     0.052613
# 4     0.053897
# 5     0.032657
# 6     0.012949
# 7     0.013829
# 8     0.019717
# 9     0.024699
# 10    0.025583
# 11    0.027078
# 12    0.031361
# 13    0.030250
# 14    0.031531
# 15    0.032125
# 16    0.033519
# 17    0.038989
# 18    0.039902
# 19    0.031366
# 20    0.039292
# 21    0.059956
# 22    0.043980
# 23    0.045087
# Name: is_arrested, dtype: float64

# %%
hourly_arrest_rate = ri.groupby(ri.index.hour).is_arrested.mean()

# %%
import matplotlib.pyplot as plt

# %%
hourly_arrest_rate.plot()
plt.xlabel('Hour')
plt.ylabel('Arrest Rate')
plt.title('Arrest Rate by Time of Day')
plt.show()

# %%
ri.drugs_related_stop.resample('A').mean()

# %%
annual_drug_rate = ri.drugs_related_stop.resample('A').mean()

# %%
annual_drug_rate.plot()
plt.show()

# %%
annual_search_rate = ri.search_conducted.resample('A').mean()

# %%
annual = pd.concat([annual_drug_rate, annual_search_rate], axis = 'columns')

# %%
annual.plot(subplots = True)
plt.show()

# %%
all_zones = pd.crosstab(ri.district, ri.violation)

# %%
all_zones.loc['Zone K1' : 'Zone K3']

# %%
k_zones = all_zones.loc['Zone K1' : 'Zone K3']

# %%
k_zones.plot(kind = 'bar')
plt.show()

# %%
k_zones.plot(kind = 'bar', stacked = True)
plt.show()

# %%
ri.stop_duration.unique()

# %%
mapping = {'0-15 Min' : 8, '16-30 Min' : 23, '30+ Min' : 45}

# %%
ri['stop_minutes'] = ri.stop_duration.map(mapping)

# %%
ri.stop_minutes.unique()

# %%
ri.groupby('violation_raw').stop_minutes.mean()

# %%
stop_length = ri.groupby('violation_raw').stop_minutes.mean()

# %%
stop_length.sort_values().plot(kind = 'barh', color = 'blue')
plt.show()

# %%
weather = pd.read_csv('weather.csv')

# %%
weather.head()

# %%
weather[['TMIN', 'TAVG', 'TMAX']].describe()

# %%
weather[['TMIN', 'TAVG', 'TMAX']].plot(kind = 'box')
plt.show()

# %%
weather['TDIFF'] = weather.TMAX - weather.TMIN

# %%
weather.TDIFF.describe()

# %%
weather.TDIFF.plot(kind = 'hist', bins = 20)
plt.show()

# %%
WT = weather.loc[:, 'WT01' : 'WT22']

# %%
weather['bad_conditions'] = WT.sum(axis = 'columns')

# %%
weather['bad_conditions'] = weather.bad_conditions.fillna(0).astype('int')

# %%
weather.bad_conditions.plot(kind = 'hist')
plt.show()

# %%
weather.bad_conditions.value_counts().sort_index()

# %%
mapping = {0:'good', 1:'bad', 2:'bad', 3:'bad', 4:'bad', 5:'worse', 6:'worse', 7:'worse', 8:'worse', 9:'worse'}

# %%
weather['rating'] = weather.bad_conditions.map(mapping)

# %%
weather.rating.value_counts()

# %%
cats = ['good', 'bad', 'worse']

# %%
weather['rating'] = weather.rating.astype('category', ordered = True, categories = cats)

# %%
weather.rating.head()

# %%
ri.reset_index(inplace = True)

# %%
ri.head()

# %%
weather_rating = weather[['DATE', 'rating']]

# %%
weather_rating.head()

# %%
ri.shape

# %%
ri_weather = pd.merge(left=ri, right=weather_rating, left_on='stop_date', right_on='DATE', how='left')

# %%
ri_weather.shape

# %%
ri_weather.set_index('stop_datetime', inplace=True)

# %%
ri_weather.is_arrested.mean()

# %%
ri_weather.groupby('rating').is_arrested.mean()

# %%
ri_weather.groupby(['violation', 'rating']).is_arrested.mean()

# %%
arrest_rate = ri_weather.groupby(['violation', 'rating']).is_arrested.mean()

# %%
arrest_rate

# %%
'the arrest rate for moving violations in bad weather is ', arrest_rate.loc['Moving violation', 'bad']

# %%
arrest_rate.loc['Speeding']

# %%
arrest_rate.unstack

# %%
ri_weather.pivot_table(index='violation', columns='rating', values='is_arrested')
